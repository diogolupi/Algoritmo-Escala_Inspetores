# %%
import pandas as pd
import random
import numpy as np

# Carregar os dados das planilhas
escala_df = pd.read_excel('/content/Escala_Final 1 (1).xlsx')
disponibilidade_df = pd.read_excel('Disponibilidade_2025.xlsx')
inspetores_df = pd.read_excel('Inspetores_2025.xlsx')
preferencia_df = pd.read_excel('Preferencia_2025.xlsx')

# Converter as colunas "Semana" para datetime
disponibilidade_df['Semana'] = pd.to_datetime(disponibilidade_df['Semana'], format='%d/%m/%Y')
escala_df['Semana'] = pd.to_datetime(escala_df['Semana'], format='%d/%m/%Y', errors='coerce')

# Cria um dicionário de preferências:
# chave: nome do inspetor; valor: nome do parceiro preferido
preferencias = dict(zip(preferencia_df['Nome'], preferencia_df['Preferência']))

def preencher_escala_corrigido_v21(escala, disponibilidade, inspetores, preferencias,
                                   max_escalas=7, priorizar_menos_escala=True):
    """
    Preenche a escala obedecendo às regras:
      - Respeitar a disponibilidade dos inspetores para cada semana.
      - Selecionar apenas os inspetores capacitados para o tipo de empresa.
      - Garantir que um inspetor não seja alocado em mais de uma empresa na mesma semana.
      - Limitar o número total de escalas por inspetor (max_escalas).
      - Evitar escalas consecutivas (exceto para a região 'C').
      - Priorizar o parceiro preferido, se disponível.
      - Garantir que pelo menos um dos inspetores seja líder.

      Apenas os tipos de empresa permitidos são processados:
        'Sólidos', 'Medicamentos', 'Estéreis', 'Insumos', 'Biológicos'

    A novidade nesta versão é que, ao selecionar os inspetores (tanto o 1º quanto o 2º),
    o algoritmo prioriza aqueles que já possuem menos dias escalados (ou seja, com
    menor número de atribuições no período), evitando que inspetores que já preencheram
    muitas semanas fiquem sempre à frente.

    Parâmetros:
      - priorizar_menos_escala: se True, dentre os candidatos elegíveis, é feita a seleção
        preferencialmente entre aqueles com menor número de escalas já marcadas.
    """
    # Converter datas para datetime, se necessário
    disponibilidade['Semana'] = pd.to_datetime(disponibilidade['Semana'], format='%d/%m/%Y', errors='coerce')
    escala['Semana'] = pd.to_datetime(escala['Semana'], format='%d/%m/%Y', errors='coerce')

    alocacao_lideres = []
    alocacao_inspetores = []
    # Dicionário que guarda os inspetores já alocados por semana (chave: semana no formato 'dd/mm/aaaa')
    inspetores_alocados_por_semana = {}
    # Histórico de escalas por inspetor (chave: nome, valor: lista de semanas escaladas)
    inspetor_historico = {}

    # Lista com os tipos permitidos
    tipos_validos = ['Sólidos', 'Medicamentos', 'Estéreis', 'Insumos', 'Biológicos']

    for i, row in escala.iterrows():
        semana_data = row['Semana']
        tipo_empresa = row['Tipo']
        regiao = row['Região']

        # Se faltar data ou tipo, deixa em branco
        if pd.isna(semana_data) or pd.isna(tipo_empresa):
            alocacao_lideres.append('')
            alocacao_inspetores.append('')
            continue

        # Se o tipo de empresa não estiver entre os tipos permitidos, pula a alocação
        if tipo_empresa not in tipos_validos:
            alocacao_lideres.append('')
            alocacao_inspetores.append('')
            continue

        # Seleciona os inspetores disponíveis para a semana
        inspetores_disponiveis = disponibilidade[disponibilidade['Semana'] == semana_data]['Inspetor'].unique()

        # Filtrar inspetores capacitados conforme o tipo de empresa
        if tipo_empresa == 'Sólidos':
            # Sólidos correspondem a Medicamentos
            inspetores_capacitados = inspetores[inspetores['Medicamentos'] != 'Não capacitado']
        elif tipo_empresa == 'Medicamentos':
            inspetores_capacitados = inspetores[inspetores['Medicamentos'] != 'Não capacitado']
        elif tipo_empresa == 'Estéreis':
            inspetores_capacitados = inspetores[inspetores['Estéreis'] != 'Não capacitado']
        elif tipo_empresa == 'Insumos':
            inspetores_capacitados = inspetores[inspetores['Insumos'] != 'Não capacitado']
        elif tipo_empresa == 'Biológicos':
            inspetores_capacitados = inspetores[inspetores['Biológicos'] != 'Não capacitado']

        # Filtrar os inspetores que estão disponíveis e capacitados
        inspetores_qualificados = inspetores_capacitados[inspetores_capacitados['Inspetor'].isin(inspetores_disponiveis)]
        if inspetores_qualificados.empty:
            alocacao_lideres.append('')
            alocacao_inspetores.append('')
            continue

        # Separar os que são líderes e os que não são
        lideres_lista = inspetores_qualificados[inspetores_qualificados['Liderança'] == 'Líder']['Inspetor'].tolist()
        nao_lideres_lista = inspetores_qualificados[inspetores_qualificados['Liderança'] == 'Não Líder']['Inspetor'].tolist()

        # Formata a semana para string (para uso no histórico e na verificação de alocação)
        semana_str = semana_data.strftime('%d/%m/%Y')
        semana_anterior = (semana_data - pd.Timedelta(days=7)).strftime('%d/%m/%Y')

        # Filtra os candidatos que:
        #  - Ainda não atingiram o limite de escalas
        #  - Não foram alocados para outra empresa nessa mesma semana
        candidatos = [
            insp for insp in (lideres_lista + nao_lideres_lista)
            if len(inspetor_historico.get(insp, [])) < max_escalas and
               insp not in inspetores_alocados_por_semana.get(semana_str, set())
        ]

        # Se a região não for 'C', evita escalas consecutivas (quem trabalhou na semana anterior)
        if regiao != 'C':
            candidatos = [insp for insp in candidatos if semana_anterior not in inspetor_historico.get(insp, [])]

        # Caso reste menos de 2 candidatos, relaxa a restrição de escalas consecutivas (mantendo a verificação da mesma semana)
        if len(candidatos) < 2:
            candidatos = [
                insp for insp in (lideres_lista + nao_lideres_lista)
                if len(inspetor_historico.get(insp, [])) < max_escalas and
                   insp not in inspetores_alocados_por_semana.get(semana_str, set())
            ]

        if len(candidatos) < 2:
            inspetor_1 = ''
            inspetor_2 = ''
        else:
            # Seleciona o inspetor 1 entre os candidatos, priorizando aqueles com menos dias já escalados
            if priorizar_menos_escala:
                min_escalas = min(len(inspetor_historico.get(insp, [])) for insp in candidatos)
                candidatos_priorizados = [insp for insp in candidatos if len(inspetor_historico.get(insp, [])) == min_escalas]
                inspetor_1 = random.choice(candidatos_priorizados)
            else:
                inspetor_1 = random.choice(candidatos)

            # Após selecionar o inspetor 1, constrói a lista de candidatos para o inspetor 2
            remaining_candidates = [insp for insp in candidatos if insp != inspetor_1]

            # Verifica se o inspetor 1 tem um parceiro preferido disponível
            parceiro_preferido = preferencias.get(inspetor_1, None)
            if parceiro_preferido and parceiro_preferido in remaining_candidates:
                # Se a priorização estiver ativa, verifica se o parceiro está entre os com menor número de escalas
                if priorizar_menos_escala:
                    min_remaining = min(len(inspetor_historico.get(insp, [])) for insp in remaining_candidates)
                    if len(inspetor_historico.get(parceiro_preferido, [])) == min_remaining:
                        inspetor_2 = parceiro_preferido
                    else:
                        candidatos2_priorizados = [insp for insp in remaining_candidates if len(inspetor_historico.get(insp, [])) == min_remaining]
                        inspetor_2 = random.choice(candidatos2_priorizados)
                else:
                    inspetor_2 = parceiro_preferido
            else:
                if remaining_candidates:
                    if priorizar_menos_escala:
                        min_remaining = min(len(inspetor_historico.get(insp, [])) for insp in remaining_candidates)
                        candidatos2_priorizados = [insp for insp in remaining_candidates if len(inspetor_historico.get(insp, [])) == min_remaining]
                        inspetor_2 = random.choice(candidatos2_priorizados)
                    else:
                        inspetor_2 = random.choice(remaining_candidates)
                else:
                    inspetor_2 = ''

            # Garante que pelo menos um dos inspetores seja líder
            if not (inspetor_1 in lideres_lista or inspetor_2 in lideres_lista):
                possiveis_lideres = [
                    insp for insp in lideres_lista
                    if len(inspetor_historico.get(insp, [])) < max_escalas and
                       insp not in inspetores_alocados_por_semana.get(semana_str, set())
                ]
                if possiveis_lideres:
                    leader_sel = random.choice(possiveis_lideres)
                    inspetor_1 = leader_sel

            # Atualiza o histórico dos inspetores (somente se houver inspetor selecionado)
            if inspetor_1:
                inspetor_historico.setdefault(inspetor_1, []).append(semana_str)
            if inspetor_2:
                inspetor_historico.setdefault(inspetor_2, []).append(semana_str)
            # Atualiza a lista de inspetores já alocados na semana
            inspetores_alocados_por_semana.setdefault(semana_str, set()).update([inspetor_1, inspetor_2])

        alocacao_lideres.append(inspetor_1)
        alocacao_inspetores.append(inspetor_2)

    escala['Inspetor 1'] = alocacao_lideres
    escala['Inspetor 2'] = alocacao_inspetores
    return escala

# Exemplo de execução:
# Aqui, a priorização é feita de forma que os inspetores com menos dias já escalados sejam escolhidos primeiro.
escala_final = preencher_escala_corrigido_v21(
    escala_df.copy(),
    disponibilidade_df,
    inspetores_df,
    preferencias,
    max_escalas=7,
    priorizar_menos_escala=True  # Altere para False se preferir a escolha puramente aleatória entre os candidatos
)

# Formata a coluna "Semana" e salva o resultado em Excel
escala_final['Semana'] = escala_final['Semana'].dt.strftime('%d/%m/%Y')
escala_final.to_excel('Escala_V21.xlsx', index=False)

# Exibe a frequência de escalas por inspetor para conferência
frequencia_escala = pd.concat([escala_final['Inspetor 1'], escala_final['Inspetor 2']]).value_counts()

# Exibe o resultado em formato de tabela markdown (se preferir, pode usar to_string ou to_markdown)
print(escala_final.to_markdown())
print('================== Frequência ==================')
print(frequencia_escala)
# Out:
# |    | Empresa                                                                           | Região   | Semana     | Inspetor 1                             | Inspetor 2                             | Tipo          |
# |---:|:----------------------------------------------------------------------------------|:---------|:-----------|:---------------------------------------|:---------------------------------------|:--------------|
# |  0 | Cristália Produtos Químicos Farmacêuticos Ltda                                    | A        | 07/04/2025 | Michelle Werneck de Oliveira           | Álvaro Lopes Stecher                   | Biológicos    |
# |  1 | HANGZHOU ZHONGMEIHUADONG PHARMACEUTICAL JIANGDONG CO., LTD. - B001165             | C        | 07/04/2025 | Maria Helena Krama                     | Fábio Ribeiro Rodrigues                | Insumos       |
# |  2 | STA PHARMACEUTICAL SWITZERLAND S.A.                                               | A        | 07/04/2025 | Felipe Augusto Gomes Sales             | Priscila Alves de Andrade              | Sólidos       |
# |  3 | NABIQASIM INDUSTRIES (PVT) LTD                                                    | C        | 07/04/2025 | Amanda da Mota Pacheco                 | José Bernardino Pereira da Silva Filho | Estéreis      |
# |  4 | SURGE LABORATORIES PRIVATE LIMITED                                                | C        | 14/04/2025 | Gláucia Ribeiro Lima Wiltgen           | Pedro Henrique Silvano da Silva        | Estéreis      |
# |  5 | AS ERVAS CURAM INDUSTRIA FARMACEUTICA LTDA                                        | A        | 14/04/2025 | Valtemir Borges da Silva               | Renato Lopes Hurtado                   | Insumos       |
# |  6 | HIKAL LIMITED                                                                     | C        | 14/04/2025 | Marcio Pessoa Costa Pinho              | Eduardo Luís Testa das Neves           | Insumos       |
# |  7 | KOLON LIFE SCIENCE CHUNGJU PLANT - B001173                                        | C        | 14/04/2025 | Nériton Ribeiro de Souza               | Ihatanderson Alves da Silva            | Insumos       |
# |  8 | ALCAMI CAROLINAS CORPORATION                                                      | A        | 14/04/2025 | Renato de Oliveira Costa               | Glória Maria de Oliveira Latuf         | Sólidos       |
# |  9 | Novamed Fabricação de Produtos Farmacêuticos Ltda - 12.424.020/0001-79 - AM       | C        | 28/04/2025 | Julia Diniz Calatrone                  | Marcelo Sidi Garcia                    | Medicamentos  |
# | 10 | WEGMED                                                                            | A        | 21/04/2025 | Fabrício Carneiro de Oliveira          | Jean Carlo de Miranda                  | Biológicos    |
# | 11 | AKUMS DRUGS & PHARMACEUTICALS LIMITED                                             | C        | 21/04/2025 | Robelma France de Oliveira Marques     | Amanda da Mota Pacheco                 | Estéreis      |
# | 12 | NANJING HENCER PHARMACEUTICAL CO., LTD                                            | C        | 21/04/2025 | Álvaro Lopes Stecher                   | Priscila Alves de Andrade              | Estéreis      |
# | 13 | RL FINE CHEM PVT. LTD - B0935                                                     | C        | 21/04/2025 | Glória Maria de Oliveira Latuf         | Eduardo Luís Testa das Neves           | Insumos       |
# | 14 | SWISS PARENTERALS LTD.                                                            | C        | 21/04/2025 | Marcio Pessoa Costa Pinho              | Pedro Henrique Silvano da Silva        | Estéreis      |
# | 15 | ATHENA DRUG DELIVERY SOLUTIONS PVT. LTD.                                          | C        | 28/04/2025 | Elenice Lacerda                        | Erieldes Sousa Silva                   | Sólidos       |
# | 16 | CATALENT MASSACHUSETTS, LLC                                                       | A        | 28/04/2025 | Felipe Augusto Gomes Sales             | Nériton Ribeiro de Souza               | Sólidos       |
# | 17 | SINOPEP-ALLSINO BIOPHARMACEUTICAL CO., LTD - B001195                              | C        | 28/04/2025 |                                        |                                        | liraglutida   |
# | 18 | SWISS_PARENTERALS_LTD                                                             | C        | 28/04/2025 | Ihatanderson Alves da Silva            | Maria Helena Krama                     | Estéreis      |
# | 19 | nan                                                                               | nan      | nan        |                                        |                                        | nan           |
# | 20 | ERIS THERAPEUTICS LTD                                                             | C        | 05/05/2025 | Katia Andrea Domingos de Morais        | Fábio Ribeiro Rodrigues                | Medicamentos  |
# | 21 | EMCURE PHARMACEUTICALS LIMITED                                                    | C        | 05/05/2025 | Robelma France de Oliveira Marques     | José Bernardino Pereira da Silva Filho | Sólidos       |
# | 22 | ZYDUS LIFESCIENCES LIMITED                                                        | C        | 05/05/2025 | Erieldes Sousa Silva                   | Gláucia Ribeiro Lima Wiltgen           | Sólidos       |
# | 23 | NOVARTIS SINGAPORE PHARMACEUTICAL MFG PTE LTD (BIOPRODUCTION OPERATION SINGAPORE) | C        | 05/05/2025 | Lílian da Costa e Silva                | Julia Diniz Calatrone                  | Biológicos    |
# | 24 | BIONTECH MANUFACTURING MARBURG GMBH - A001497                                     | A        | 05/05/2025 | Jean Carlo de Miranda                  | Marcio Pessoa Costa Pinho              | Estéreis      |
# | 25 | DR. REDDY'S LABORATORIES LIMITED, BIOLOGICS                                       | C        | 05/05/2025 | Maria Helena Krama                     | Álvaro Lopes Stecher                   | Estéreis      |
# | 26 | AURISCO PHARMACEUTICAL LIMITED - B0184                                            | C        | 12/05/2025 | Fernanda Moreira Coura                 | Marcos Antonio Ferreira Gomes          | Insumos       |
# | 27 | NOVARTIS PHARMA SCHWEIZERHALLE AG                                                 | A        | 12/05/2025 | Carlos César dos Santos Nogueira       | Rafael Antônio Dalfior Fava            | Sólidos       |
# | 28 | FORMIL QUÍMICA LTDA                                                               | A        | 12/05/2025 | Alexandre Lindolfo Modesto             | Valtemir Borges da Silva               | Insumos       |
# | 29 | MAPRIMED S.A. - B0334                                                             | A        | 12/05/2025 | Elenice Lacerda                        | Michelle Werneck de Oliveira           | Insumos       |
# | 30 | EVER PHARMA JENA GMBH                                                             | C        | 12/05/2025 | Katia Andrea Domingos de Morais        | Fabrício Carneiro de Oliveira          | Estéreis      |
# | 31 | ASPEN NOTRE DAME DE BONDEVILLE                                                    | C        | 19/05/2025 | Rafael Filiacci Bovi                   | Gleiciely Santos Silveira              | Estéreis      |
# | 32 | RAY LIFE SCIENCES PVT LTD                                                         | A        | 19/05/2025 | Lílian da Costa e Silva                | Amanda da Mota Pacheco                 | Estéreis      |
# | 33 | Laboratório Saúde Ltda. - RS                                                      | C        | 19/05/2025 | Carlos César dos Santos Nogueira       | Fernanda Moreira Coura                 | Medicamentos  |
# | 34 | JIANGSU XIDI PHARMACEUTICALS CO., LTD                                             | C        | 19/05/2025 | Thaila Coradassi de Almeida            | Marcos Antonio Ferreira Gomes          | Insumos       |
# | 35 | WUHAN GRAND HOYO CO., LTD. - B001106                                              | C        | 19/05/2025 | Alexandre Lindolfo Modesto             | Valtemir Borges da Silva               | Insumos       |
# | 36 | VILLAS BOAS RADIOFÁRMACOS BRASIL S/A - 08.944.601/0001-64 - DF                    | C        | 19/05/2025 |                                        |                                        | Radiofármacos |
# | 37 | VILLAS BOAS RADIOFÁRMACOS BRASIL S/A - 08.944.601/0002-45 - CE                    | C        | nan        |                                        |                                        | nan           |
# | 38 | Curia Spain S.A.U.  - B000339                                                     | A        | 26/05/2025 | Renato de Oliveira Costa               | Marcelo Sidi Garcia                    | Insumos       |
# | 39 | HENAN TOPFOND SCI-TECH CO LTD - B001169                                           | C        | 26/05/2025 | Rafael Filiacci Bovi                   | Katia Andrea Domingos de Morais        | Insumos       |
# | 40 | ZHEJIANG AUSUN PHARMACEUTICAL CO., LTD. - B001181                                 | C        | 26/05/2025 | Julia Diniz Calatrone                  | Lílian da Costa e Silva                | Insumos       |
# | 41 | MEDISPRAY LABORATORIES PVT. LTD                                                   | C        | 26/05/2025 | José Bernardino Pereira da Silva Filho | Priscila Alves de Andrade              | Medicamentos  |
# | 42 | TECNANDINA S.A                                                                    | A        | 26/05/2025 | Nériton Ribeiro de Souza               | Ihatanderson Alves da Silva            | Sólidos       |
# | 43 | nan                                                                               | nan      | nan        |                                        |                                        | nan           |
# | 44 | nan                                                                               | nan      | nan        |                                        |                                        | nan           |
# | 45 | KLOCKE PHARMA-SERVICE GMBH                                                        | A        | 02/06/2025 | Eduardo Luís Testa das Neves           | Jean Carlo de Miranda                  | Sólidos       |
# | 46 | HAINAN POLY PHARM, CO., LTD                                                       | C        | 02/06/2025 | Carlos César dos Santos Nogueira       | Rafael Filiacci Bovi                   | Insumos       |
# | 47 | LUPIN LIMITED (DABHASA) - B0251                                                   | C        | 02/06/2025 | Felipe Augusto Gomes Sales             | Erieldes Sousa Silva                   | Insumos       |
# | 48 | Laboratório Extratos Alergênicos Ltda                                             | A        | 02/06/2025 | Katia Andrea Domingos de Morais        | Fabrício Carneiro de Oliveira          | Biológicos    |
# | 49 | WANBURY LTD. - UNIT RAIGAD - B0075                                                | C        | 09/06/2025 | Fernanda Moreira Coura                 | Pedro Henrique Silvano da Silva        | Insumos       |
# | 50 | INTAS PHARMACEUTICALS LIMITED                                                     | C        | 09/06/2025 | Gláucia Ribeiro Lima Wiltgen           | Robelma France de Oliveira Marques     | Estéreis      |
# | 51 | BIOCON LIMITED                                                                    | C        | 09/06/2025 | Glória Maria de Oliveira Latuf         | Michelle Werneck de Oliveira           | Insumos       |
# | 52 | ADIMMUNE CORPORATION                                                              | C        | 16/06/2025 | Robelma France de Oliveira Marques     | Eduardo Luís Testa das Neves           | Biológicos    |
# | 53 | Famar Health Car                                                                  | A        | 16/06/2025 | Renato Lopes Hurtado                   | Erieldes Sousa Silva                   | Sólidos       |
# | 54 | Intas_Pharmaceuticals_Limited                                                     | C        | 16/06/2025 | Ihatanderson Alves da Silva            | Pedro Henrique Silvano da Silva        | Sólidos       |
# | 55 | MSN LIFE SCIENCES PRIVATE LIMITED                                                 | C        | 16/06/2025 | Jean Carlo de Miranda                  | Glória Maria de Oliveira Latuf         | Insumos       |
# | 56 | GLAXOSMITHKLINE MANUFACTURING S.P.A.                                              | A        | 23/06/2025 | Gleiciely Santos Silveira              | Thaila Coradassi de Almeida            | Biológicos    |
# | 57 | BIOSPRING BIOTECHNOLOGY GMBH - B0929                                              | A        | 23/06/2025 | Alexandre Lindolfo Modesto             | Elenice Lacerda                        | Insumos       |
# | 58 | JILIN ASYMCHEM LABORATORIES CO LTD B. 1131                                        | C        | 23/06/2025 | Renato de Oliveira Costa               | Maria Helena Krama                     | Insumos       |
# | 59 | SHILPA MEDICARE LIMITED - B0164                                                   | C        | 30/06/2025 | Gleiciely Santos Silveira              | Marcelo Sidi Garcia                    | Insumos       |
# | 60 | Laboratórios Bagó do Brasil S.A - 04.748.181/0009-47 - ES                         | C        | 30/06/2025 | José Bernardino Pereira da Silva Filho | Priscila Alves de Andrade              | Medicamentos  |
# | 61 | RECKITT BENCKISER HEALTHCARE MANUFATURING                                         | C        | 30/06/2025 | Elenice Lacerda                        | Álvaro Lopes Stecher                   | Medicamentos  |
# | 62 | BIOCON LIMITED A000106                                                            | C        | 30/06/2025 | Marcio Pessoa Costa Pinho              | Lílian da Costa e Silva                | Estéreis      |
# | 63 | BIOZENTA LIFESCIENCE PVT. LTD                                                     | C        | 30/06/2025 | Amanda da Mota Pacheco                 | Michelle Werneck de Oliveira           | Estéreis      |
# | 64 | STGEN BIO CO., LTD                                                                | C        | 30/06/2025 | Renato de Oliveira Costa               | Julia Diniz Calatrone                  | Estéreis      |
# | 65 | Farmace Indústria Químico-Farmacêutica Cearense Ltda. - 06.628.333/0001-46 - CE   | C        | 14/07/2025 | Felipe Augusto Gomes Sales             | Eduardo Luís Testa das Neves           | Medicamentos  |
# ================== Frequência ==================
#                                           12
# Eduardo Luís Testa das Neves               5
# Michelle Werneck de Oliveira               4
# Glória Maria de Oliveira Latuf             4
# Pedro Henrique Silvano da Silva            4
# Priscila Alves de Andrade                  4
# José Bernardino Pereira da Silva Filho     4
# Jean Carlo de Miranda                      4
# Lílian da Costa e Silva                    4
# Maria Helena Krama                         4
# Katia Andrea Domingos de Morais            4
# Ihatanderson Alves da Silva                4
# Elenice Lacerda                            4
# Erieldes Sousa Silva                       4
# Álvaro Lopes Stecher                       4
# Marcio Pessoa Costa Pinho                  4
# Robelma France de Oliveira Marques         4
# Felipe Augusto Gomes Sales                 4
# Amanda da Mota Pacheco                     4
# Renato de Oliveira Costa                   4
# Julia Diniz Calatrone                      4
# Nériton Ribeiro de Souza                   3
# Fernanda Moreira Coura                     3
# Carlos César dos Santos Nogueira           3
# Rafael Filiacci Bovi                       3
# Fabrício Carneiro de Oliveira              3
# Valtemir Borges da Silva                   3
# Gláucia Ribeiro Lima Wiltgen               3
# Gleiciely Santos Silveira                  3
# Marcelo Sidi Garcia                        3
# Alexandre Lindolfo Modesto                 3
# Marcos Antonio Ferreira Gomes              2
# Thaila Coradassi de Almeida                2
# Fábio Ribeiro Rodrigues                    2
# Renato Lopes Hurtado                       2
# Rafael Antônio Dalfior Fava                1
# Name: count, dtype: int64
